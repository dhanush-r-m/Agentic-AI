# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
import os
gemini_api_key = os.getenv('GOOGLE_API_KEY')

# %%
from google import genai

# %%
client = genai.Client(api_key=gemini_api_key)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
messages = ["what is the capital of france?"]

# %%
response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = messages
)

print(response.text)
# Out:
# The capital of France is **Paris**.

# %%
question = "What is generative ai and and Ai Agents?"

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = question
)

answer = response.text

print(answer)
# Out:
# Let's break down Generative AI and AI Agents, two distinct but often complementary concepts in the world of artificial intelligence.
#
# ---
#
# ## What is Generative AI?
#
# **Generative AI** refers to a category of AI models that can **produce new and original content** across various modalities (text, images, audio, video, code, etc.) that resembles the data they were trained on, but isn't an exact copy. Instead of just classifying, predicting, or analyzing existing data, generative models *create* it.
#
# **Key Characteristics:**
#
# 1.  **Creation, Not Just Prediction:** Its primary function is to generate novel output, rather than just identifying patterns in existing data (like traditional discriminative AI).
# 2.  **Learns Patterns:** It learns the underlying patterns, structures, and relationships within a vast dataset (e.g., millions of images, billions of text paragraphs).
# 3.  **Variability and Diversity:** Given the same prompt, a generative model can often produce multiple different, yet plausible, outputs, showcasing creativity and variety.
# 4.  **Foundation Models:** Many powerful generative AIs are "foundation models" – large models trained on vast amounts of data that can be adapted for a wide range of downstream tasks.
#
# **How it Works (Simplified):**
#
# Imagine a model that has "read" almost the entire internet (for text) or seen billions of images (for visual tasks). It doesn't just memorize; it learns the *rules* and *styles* of how text is structured, how objects look, how colors combine, etc. When you give it a prompt (e.g., "write a poem about a flying cat" or "create an image of a futuristic city"), it uses these learned rules to construct something entirely new that fits your request.
#
# **Examples of Generative AI:**
#
# *   **Text:** ChatGPT, Google Bard, Claude (can write essays, emails, code, scripts, poems, summarize text).
# *   **Images:** DALL-E, Midjourney, Stable Diffusion (can create images from text descriptions).
# *   **Audio:** Models that generate music, realistic speech, or sound effects.
# *   **Video:** Models that generate short video clips from text or images.
# *   **Code:** Models that write, complete, or debug code in various programming languages.
#
# **Why it's Important:**
# Generative AI is revolutionizing content creation, design, software development, education, and many other fields by significantly lowering the barrier to creating high-quality, original content.
#
# ---
#
# ## What are AI Agents?
#
# An **AI Agent** is an autonomous or semi-autonomous software entity that can **perceive its environment, reason about its observations, make decisions, and take actions** to achieve specific goals, often interacting with other systems or the real world. Think of it as an AI with a mission and the tools to pursue it.
#
# **Key Characteristics:**
#
# 1.  **Goal-Oriented:** Agents are designed to achieve one or more specific objectives.
# 2.  **Perception:** They can gather information from their environment (e.g., reading web pages, analyzing data, interpreting user input).
# 3.  **Reasoning/Planning:** They can process information, understand context, plan a sequence of steps, and make decisions to reach their goal.
# 4.  **Action:** They can interact with their environment by performing actions (e.g., sending emails, browsing the web, calling APIs, writing code, controlling hardware).
# 5.  **Autonomy:** They can operate without constant human intervention, making choices based on their programming and perceived environment.
# 6.  **Memory/Learning (Optional but common):** They can remember past interactions, learn from outcomes, and adapt their behavior over time.
#
# **How it Works (The Agent Loop):**
#
# A typical AI Agent operates in a continuous loop:
# *   **Perceive:** Observe the current state of the environment and gather relevant information.
# *   **Analyze/Reason:** Process the perceived information, understand the problem, and determine the next logical step toward the goal. This often involves breaking down complex goals into smaller sub-tasks.
# *   **Plan:** Formulate a strategy or sequence of actions to address the current sub-task or the overall goal.
# *   **Act:** Execute the planned actions.
# *   **Repeat:** Go back to perceiving the new state after the action and continue the loop until the goal is achieved or deemed impossible.
#
# **Relationship to Generative AI:**
#
# Generative AI, particularly large language models (LLMs), are increasingly becoming the **"brain" or "reasoning engine"** within AI Agents.
# *   An LLM can be used by an agent to **reason through a problem**, **generate a plan of action**, **write code** for a specific task, **create natural language responses** to user queries, or even **interpret complex instructions**.
# *   The agent then uses its "tools" (APIs, web browser, file system access, other software) to execute the plan or interact with the world, guided by the LLM's reasoning.
#
# **Examples of AI Agents:**
#
# *   **Task Automation Bots:** An agent that can automatically book flights, manage calendars, or answer customer service queries by interacting with various online services.
# *   **Personal Assistants:** More advanced versions of Siri or Google Assistant that can proactively manage tasks, conduct research, and interact with multiple applications on your behalf.
# *   **Code Assistants:** Agents that can not only generate code but also understand error messages, propose fixes, and even run tests.
# *   **Research Agents:** Agents that can browse the internet, synthesize information from multiple sources, and generate reports on a given topic.
# *   **Auto-GPT, BabyAGI (experimental):** Early, more conceptual examples of open-source projects demonstrating how an LLM can be given a goal and autonomously generate and execute tasks (like web browsing, code writing, and file management) to achieve it.
#
# **Why it's Important:**
# AI Agents promise to automate complex, multi-step tasks, act as intelligent assistants that go beyond simple commands, and enable more sophisticated and proactive interactions between humans and technology. They aim to move AI from being a tool you use to a partner that works on your behalf.

# %%
from IPython.display import display, Markdown
display(Markdown(f"**Q:** {question}\n\n**A:** {answer}"))
# Out:
# **Q:** What is generative ai and and Ai Agents?
#
# **A:** Let's break down Generative AI and AI Agents, two distinct but often complementary concepts in the world of artificial intelligence.
#
# ---
#
# ## What is Generative AI?
#
# **Generative AI** refers to a category of AI models that can **produce new and original content** across various modalities (text, images, audio, video, code, etc.) that resembles the data they were trained on, but isn't an exact copy. Instead of just classifying, predicting, or analyzing existing data, generative models *create* it.
#
# **Key Characteristics:**
#
# 1.  **Creation, Not Just Prediction:** Its primary function is to generate novel output, rather than just identifying patterns in existing data (like traditional discriminative AI).
# 2.  **Learns Patterns:** It learns the underlying patterns, structures, and relationships within a vast dataset (e.g., millions of images, billions of text paragraphs).
# 3.  **Variability and Diversity:** Given the same prompt, a generative model can often produce multiple different, yet plausible, outputs, showcasing creativity and variety.
# 4.  **Foundation Models:** Many powerful generative AIs are "foundation models" – large models trained on vast amounts of data that can be adapted for a wide range of downstream tasks.
#
# **How it Works (Simplified):**
#
# Imagine a model that has "read" almost the entire internet (for text) or seen billions of images (for visual tasks). It doesn't just memorize; it learns the *rules* and *styles* of how text is structured, how objects look, how colors combine, etc. When you give it a prompt (e.g., "write a poem about a flying cat" or "create an image of a futuristic city"), it uses these learned rules to construct something entirely new that fits your request.
#
# **Examples of Generative AI:**
#
# *   **Text:** ChatGPT, Google Bard, Claude (can write essays, emails, code, scripts, poems, summarize text).
# *   **Images:** DALL-E, Midjourney, Stable Diffusion (can create images from text descriptions).
# *   **Audio:** Models that generate music, realistic speech, or sound effects.
# *   **Video:** Models that generate short video clips from text or images.
# *   **Code:** Models that write, complete, or debug code in various programming languages.
#
# **Why it's Important:**
# Generative AI is revolutionizing content creation, design, software development, education, and many other fields by significantly lowering the barrier to creating high-quality, original content.
#
# ---
#
# ## What are AI Agents?
#
# An **AI Agent** is an autonomous or semi-autonomous software entity that can **perceive its environment, reason about its observations, make decisions, and take actions** to achieve specific goals, often interacting with other systems or the real world. Think of it as an AI with a mission and the tools to pursue it.
#
# **Key Characteristics:**
#
# 1.  **Goal-Oriented:** Agents are designed to achieve one or more specific objectives.
# 2.  **Perception:** They can gather information from their environment (e.g., reading web pages, analyzing data, interpreting user input).
# 3.  **Reasoning/Planning:** They can process information, understand context, plan a sequence of steps, and make decisions to reach their goal.
# 4.  **Action:** They can interact with their environment by performing actions (e.g., sending emails, browsing the web, calling APIs, writing code, controlling hardware).
# 5.  **Autonomy:** They can operate without constant human intervention, making choices based on their programming and perceived environment.
# 6.  **Memory/Learning (Optional but common):** They can remember past interactions, learn from outcomes, and adapt their behavior over time.
#
# **How it Works (The Agent Loop):**
#
# A typical AI Agent operates in a continuous loop:
# *   **Perceive:** Observe the current state of the environment and gather relevant information.
# *   **Analyze/Reason:** Process the perceived information, understand the problem, and determine the next logical step toward the goal. This often involves breaking down complex goals into smaller sub-tasks.
# *   **Plan:** Formulate a strategy or sequence of actions to address the current sub-task or the overall goal.
# *   **Act:** Execute the planned actions.
# *   **Repeat:** Go back to perceiving the new state after the action and continue the loop until the goal is achieved or deemed impossible.
#
# **Relationship to Generative AI:**
#
# Generative AI, particularly large language models (LLMs), are increasingly becoming the **"brain" or "reasoning engine"** within AI Agents.
# *   An LLM can be used by an agent to **reason through a problem**, **generate a plan of action**, **write code** for a specific task, **create natural language responses** to user queries, or even **interpret complex instructions**.
# *   The agent then uses its "tools" (APIs, web browser, file system access, other software) to execute the plan or interact with the world, guided by the LLM's reasoning.
#
# **Examples of AI Agents:**
#
# *   **Task Automation Bots:** An agent that can automatically book flights, manage calendars, or answer customer service queries by interacting with various online services.
# *   **Personal Assistants:** More advanced versions of Siri or Google Assistant that can proactively manage tasks, conduct research, and interact with multiple applications on your behalf.
# *   **Code Assistants:** Agents that can not only generate code but also understand error messages, propose fixes, and even run tests.
# *   **Research Agents:** Agents that can browse the internet, synthesize information from multiple sources, and generate reports on a given topic.
# *   **Auto-GPT, BabyAGI (experimental):** Early, more conceptual examples of open-source projects demonstrating how an LLM can be given a goal and autonomously generate and execute tasks (like web browsing, code writing, and file management) to achieve it.
#
# **Why it's Important:**
# AI Agents promise to automate complex, multi-step tasks, act as intelligent assistants that go beyond simple commands, and enable more sophisticated and proactive interactions between humans and technology. They aim to move AI from being a tool you use to a partner that works on your behalf.
