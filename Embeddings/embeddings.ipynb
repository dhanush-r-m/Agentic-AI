# %%
import os
from dotenv import load_dotenv
load_dotenv() # Load environment variables from .env file
# Out:
# False

# %%
os.environ['OPENAI_API_KEY'] = 'your_openai_api_key_here'  # Set your OpenAI API key

# %%
from openai import OpenAIEmbeddings
embeddings = OPENAIEmbeddings(model = "text-embeddiong-3-large")
embeddings

# %%
text = "this is a sample text for embedding."
query_result = embedding.embed_query(text)
query_result ## coverts the text into a vector representation

# %%
query_result[0:5]  # Display the first 5 elements of the query result vector
query_result

# %%
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large", dimensions = 1024)

# %%
embeddings_1024

# %%
text = "this is a sample text for embedding."
query_result = embeddings_1024.embed_query(text)
query_result ## this helps in convertiing the text into a vector with 1024 dimensions

# %%
## Vector Embedding and Vector Store
from langchain.community.vectorstores import Chroma
db = Chroma.from_documents(final_docs, embeddings_1024)
db

# %%
query = "It will be all the easier for the us the conduct of the future to be a success if we can make it a success in the present."
retervied_results = db.similarity_search(query)
print(retervied_results)
